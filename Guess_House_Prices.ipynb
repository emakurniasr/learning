# %% [markdown]
# <a href="https://colab.research.google.com/github/emakurniasr/learning/blob/main/Guess_House_Prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
# GRADED FUNCTION: house_model
def house_model(y_new):
    xs = np.array([1, 2, 3, 4], dtype=int)# Your Code Here#
    ys = np.array([100, 150, 200, 250], dtype=int)# Your Code Here#
    
    model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])# Your Code Here#
    model.compile(optimizer='sgd', loss='mean_squared_error')
    model.fit(xs, ys, epochs=500)
    return model.predict(y_new)[0]

# %%
prediction = house_model([7.0])
print(prediction)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 217ms/step - loss: 35151.7109
# Epoch 2/500
# 1/1 [==============================] - 0s 4ms/step - loss: 24433.6211
# Epoch 3/500
# 1/1 [==============================] - 0s 5ms/step - loss: 16996.3125
# Epoch 4/500
# 1/1 [==============================] - 0s 12ms/step - loss: 11835.4678
# Epoch 5/500
# 1/1 [==============================] - 0s 3ms/step - loss: 8254.2168
# Epoch 6/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5769.0107
# Epoch 7/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4044.3306
# Epoch 8/500
# 1/1 [==============================] - 0s 4ms/step - loss: 2847.3635
# Epoch 9/500
# 1/1 [==============================] - 0s 12ms/step - loss: 2016.5686
# Epoch 10/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1439.8528
# Epoch 11/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1039.4397
# Epoch 12/500
# ...
